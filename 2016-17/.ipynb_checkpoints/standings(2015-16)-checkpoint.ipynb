# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplsoccer
import highlight_text #to install make sure you do pip install highlight-text in your command line
from mplsoccer import Bumpy, FontManager, add_image
import numpy as np
import json
from urllib.request import urlopen
from PIL import Image
from io import BytesIO
import requests

# %%
df = pd.read_csv('C:\\Users\\Amin\\Documents\\manutd(2012-2021)\\standings(15-16).csv')

# %%
df.head()
# Out:
#      Team  Leicester  Arsenal  Tottenham  Man City  Man Utd
# 0  Week 1          2       19         16         1        7
# 1  Week 2          2       11         14         1        4
# 2  Week 3          2        9         16         1        4
# 3  Week 4          3        6         16         1        5
# 4  Week 5          2        4         12         1        3

# %%
df=df.T

# %%
df.head()
# Out:
#                0       1       2       3       4       5       6       7   \
# Team       Week 1  Week 2  Week 3  Week 4  Week 5  Week 6  Week 7  Week 8
# Leicester       2       2       2       3       2       4       8       5
# Arsenal        19      11       9       6       4       5       4       2
# Tottenham      16      14      16      16      12       9       6       8
# Man City        1       1       1       1       1       1       2       1
#
#                8        9   ...       28       29       30       31       32  \
# Team       Week 9  Week 10  ...  Week 29  Week 30  Week 31  Week 32  Week 33
# Leicester       5        5  ...        1        1        1        1        1
# Arsenal         2        2  ...        3        3        3        3        3
# Tottenham       7        6  ...        2        2        2        2        2
# Man City        1        1  ...        4        4        4        4        4
#
#                 33       34       35       36       37
# Team       Week 34  Week 35  Week 36  Week 37  Week 38
# Leicester        1        1        1        1        1
# Arsenal          3        4        3        3        2
# Tottenham        2        2        2        2        3
# Man City         4        3        4        4        4
#
# [5 rows x 38 columns]

# %%
#reset the column names so that we drop the transposed team names
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
df.head()
# Out:
# Team      Week 1 Week 2 Week 3 Week 4 Week 5 Week 6 Week 7 Week 8 Week 9  \
# Leicester      2      2      2      3      2      4      8      5      5
# Arsenal       19     11      9      6      4      5      4      2      2
# Tottenham     16     14     16     16     12      9      6      8      7
# Man City       1      1      1      1      1      1      2      1      1
# Man Utd        7      4      4      5      3      2      1      3      3
#
# Team      Week 10  ... Week 29 Week 30 Week 31 Week 32 Week 33 Week 34  \
# Leicester       5  ...       1       1       1       1       1       1
# Arsenal         2  ...       3       3       3       3       3       3
# Tottenham       6  ...       2       2       2       2       2       2
# Man City        1  ...       4       4       4       4       4       4
# Man Utd         4  ...       6       6       6       5       5       5
#
# Team      Week 35 Week 36 Week 37 Week 38
# Leicester       1       1       1       1
# Arsenal         4       3       3       2
# Tottenham       2       2       2       3
# Man City        3       4       4       4
# Man Utd         5       5       5       5
#
# [5 rows x 38 columns]

# %%
df=df.T

# %%
df.head()
# Out:
#        Leicester Arsenal Tottenham Man City Man Utd
# Team
# Week 1         2      19        16        1       7
# Week 2         2      11        14        1       4
# Week 3         2       9        16        1       4
# Week 4         3       6        16        1       5
# Week 5         2       4        12        1       3

# %%
week = ['Week ' + str(num) for num in range(1,39)]

# %%
#highlight dictionary to pass in the color. search team color codes in google to get your teams hex colors
highlight_dict = {
    'Leicester':'#034694',
    'Arsenal':'#EDBB00',
    'Tottenham':'#FFFFFF',
    'Man City':'#6CABDD',
    'Man Utd':'#DA291C'
}

# %%
bumpy = Bumpy(
    scatter_color = '#282828', line_color = '#252525',
    rotate_xticks=90,
    ticklabel_size = 15,
    scatter_primary = 'D',
    show_right = True,
    plot_labels = True,
    alignment_yvalue=.1,
    alignment_xvalue = .065
)

# %%
fig,ax = bumpy.plot(
    x_list = week,
    y_list = np.linspace(1,20,20).astype(int),
    values = df,
    secondary_alpha = .5,
    highlight_dict = highlight_dict,
    figsize = (18,18),
    y_label = 'Position',
    ylim = (-.1,22),
    lw = 2.5
)

fig.text(s = 'Premier League (16/17) Through Week 38',x = .5, y = .89,
         c = 'white',size=24,weight='bold',ha='center'
        )
highlight_text.fig_text(x=.5, y= .88, 
                       s = 'Comparing <Leicester>, ,<Arsenal>,<Tottenham>,<Man City>, & <Man United>',
                       highlight_textprops = [
                           {"color":'#034694'},
                           {"color":'#EDBB00'},
                           {"color":'#FFFFFF'},
                           {"color":'#6CABDD'},
                           {"color":'#DA291C'}
                       ],
                        fontsize = 20,
                        color = '#C0C0C0',
                        ha='center'
                       )

ax2 = fig.add_axes([.10,.83,.11,.10])
ax2.axis('off')
img = Image.open('C:\\Users\\Amin\\Documents\\manutd(2012-2021)\\PLicon.png')
ax2.imshow(img)
