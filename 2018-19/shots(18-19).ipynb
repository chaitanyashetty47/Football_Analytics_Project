# %%
import pandas as pd
import matplotlib.pyplot as plt
from soccerplots.radar_chart import Radar
from mplsoccer import Radar, FontManager
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\Amin\\Documents\\manutd(2012-2021)\\shots(18-19).csv')

# %%
df.head()
# Out:
#           Squad  Players Used  90s  Gls   Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  \
# 0       Arsenal            28   38   69  466  159  34.1  12.26    4.18  0.14
# 1   Bournemouth            28   38   55  432  153  35.4  11.37    4.03  0.11
# 2      Brighton            21   38   35  366  100  27.3   9.63    2.63  0.08
# 3       Burnley            23   38   43  356  114  32.0   9.37    3.00  0.12
# 4  Cardiff City            25   38   33  408  112  27.5  10.74    2.95  0.07
#
#    G/SoT  Dist  FK  PK  PKatt    xG  npxG  npxG/Sh  G-xG  np:G-xG
# 0   0.41  16.2  11   4      5  58.0  54.1     0.12  11.0     10.9
# 1   0.31  16.5  14   7      9  54.4  47.6     0.11   0.6      0.4
# 2   0.30  16.9  12   5      6  34.1  29.6     0.08   0.9      0.4
# 3   0.36  15.1  14   2      2  40.7  39.2     0.11   2.3      1.8
# 4   0.27  16.9  13   3      4  39.5  36.5     0.09  -6.5     -6.5

# %%
df = df.drop(['Players Used','90s','FK','PK','PKatt'],axis=1)

# %%
df
# Out:
#               Squad  Gls   Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  G/SoT  Dist  \
# 0           Arsenal   69  466  159  34.1  12.26    4.18  0.14   0.41  16.2
# 1       Bournemouth   55  432  153  35.4  11.37    4.03  0.11   0.31  16.5
# 2          Brighton   35  366  100  27.3   9.63    2.63  0.08   0.30  16.9
# 3           Burnley   43  356  114  32.0   9.37    3.00  0.12   0.36  15.1
# 4      Cardiff City   33  408  112  27.5  10.74    2.95  0.07   0.27  16.9
# 5           Chelsea   61  596  190  31.9  15.68    5.00  0.09   0.29  17.3
# 6    Crystal Palace   48  487  136  27.9  12.82    3.58  0.08   0.28  17.0
# 7           Everton   53  490  159  32.4  12.89    4.18  0.10   0.32  16.2
# 8            Fulham   33  441  136  30.8  11.61    3.58  0.07   0.23  18.3
# 9      Huddersfield   20  398  115  28.9  10.47    3.03  0.05   0.17  18.2
# 10   Leicester City   48  508  173  34.1  13.37    4.55  0.08   0.25  17.8
# 11        Liverpool   86  569  211  37.1  14.97    5.55  0.14   0.37  16.3
# 12  Manchester City   91  673  249  37.0  17.71    6.55  0.13   0.35  16.4
# 13   Manchester Utd   65  513  211  41.1  13.50    5.55  0.11   0.27  18.1
# 14    Newcastle Utd   41  434  135  31.1  11.42    3.55  0.09   0.30  18.1
# 15      Southampton   44  483  153  31.7  12.71    4.03  0.08   0.26  18.2
# 16        Tottenham   66  533  185  34.7  14.03    4.87  0.12   0.34  17.2
# 17          Watford   51  433  151  34.9  11.39    3.97  0.12   0.33  16.6
# 18         West Ham   51  439  147  33.5  11.55    3.87  0.10   0.31  16.5
# 19           Wolves   46  467  141  30.2  12.29    3.71  0.09   0.30  17.3
#
#       xG  npxG  npxG/Sh  G-xG  np:G-xG
# 0   58.0  54.1     0.12  11.0     10.9
# 1   54.4  47.6     0.11   0.6      0.4
# 2   34.1  29.6     0.08   0.9      0.4
# 3   40.7  39.2     0.11   2.3      1.8
# 4   39.5  36.5     0.09  -6.5     -6.5
# 5   58.3  54.5     0.09   2.7      1.5
# 6   50.8  42.8     0.09  -2.8     -4.8
# 7   47.3  43.3     0.09   5.7      7.7
# 8   39.0  36.7     0.08  -6.0     -5.7
# 9   29.3  28.5     0.07  -9.3     -9.5
# 10  49.6  44.5     0.09  -1.6     -1.5
# 11  74.8  69.5     0.12  11.2      9.5
# 12  82.0  78.9     0.12   9.0      9.1
# 13  59.4  50.2     0.10   5.6      5.8
# 14  39.6  37.3     0.09   1.4      2.7
# 15  46.1  42.5     0.09  -2.1     -2.5
# 16  57.9  54.9     0.10   8.1      7.1
# 17  48.1  47.3     0.11   2.9      2.7
# 18  48.2  44.5     0.10   2.8      1.5
# 19  49.0  45.9     0.10  -3.0     -3.9

# %%
min_range = []
max_range = []

#get parameters
params = list(df.columns)
params = params[1:]
params
# Out:
# ['Gls',
#  'Sh',
#  'SoT',
#  'SoT%',
#  'Sh/90',
#  'SoT/90',
#  'G/Sh',
#  'G/SoT',
#  'Dist',
#  'xG',
#  'npxG',
#  'npxG/Sh',
#  'G-xG',
#  'np:G-xG']

# %%
#finding max and min Goals scored
min_Gls = min(df[params]['Gls'])
max_Gls = max(df[params]['Gls'])
min_range.append(min_Gls)
max_range.append(max_Gls)

#finding max and min Shots
min_Sh = min(df[params]['Sh'])
max_Sh = max(df[params]['Sh'])
min_range.append(min_Sh)
max_range.append(max_Sh)

#finding max and min Shots on Target
min_SoT = min(df[params]['SoT'])
max_SoT = max(df[params]['SoT'])
min_range.append(min_SoT)
max_range.append(max_SoT)

#finding max and min Shots on Target %
min_SoTp = min(df[params]['SoT%'])
max_SoTp = max(df[params]['SoT%'])
min_range.append(min_SoTp)
max_range.append(max_SoTp)

#finding max and min Shots per 90
min_Shp90 = min(df[params]['Sh/90'])
max_Shp90 = max(df[params]['Sh/90'])
min_range.append(min_Shp90)
max_range.append(max_Shp90)

#finding max and min Shots on Target per 90
min_SoTp90 = min(df[params]['SoT/90'])
max_SoTp90 = max(df[params]['SoT/90'])
min_range.append(min_SoTp90)
max_range.append(max_SoTp90)

#finding max and min Goals per Shots
min_GpSh = min(df[params]['G/Sh'])
max_GpSh = max(df[params]['G/Sh'])
min_range.append(min_GpSh)
max_range.append(max_GpSh)

#finding max and min Goals per Shots on Target
min_GpSoT = min(df[params]['G/SoT'])
max_GpSoT = max(df[params]['G/SoT'])
min_range.append(min_GpSoT)
max_range.append(max_GpSoT)

#finding max and min Dist
min_Dist = min(df[params]['Dist'])
max_Dist = max(df[params]['Dist'])
min_range.append(min_Dist)
max_range.append(max_Dist)

#finding max and min Expected Goals(xG)
min_xG = min(df[params]['xG'])
max_xG = max(df[params]['xG'])
min_range.append(min_xG)
max_range.append(max_xG)

#finding max and min Non-penalty Expected Goals(npxG)
min_npxG = min(df[params]['npxG'])
max_npxG = max(df[params]['npxG'])
min_range.append(min_npxG)
max_range.append(max_npxG)

#finding max and min Non-penalty xG per Shots
min_npxGpSh = min(df[params]['npxG/Sh'])
max_npxGpSh = max(df[params]['npxG/Sh'])
min_range.append(min_npxGpSh)
max_range.append(max_npxGpSh)

#finding max and min Goals -  xG
min_GmxG = min(df[params]['G-xG'])
max_GmxG = max(df[params]['G-xG'])
min_range.append(min_GmxG)
max_range.append(max_GmxG)

#finding max and min Non-penalty Goals - Expected Goals
min_npGmxG = min(df[params]['np:G-xG'])
max_npGmxG = max(df[params]['np:G-xG'])
min_range.append(min_npGmxG)
max_range.append(max_npGmxG)

# %%
df = df[df['Squad']=='Manchester Utd'].reset_index()

# %%
df
# Out:
#    index           Squad  Gls   Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  G/SoT  \
# 0     13  Manchester Utd   65  513  211  41.1   13.5    5.55  0.11   0.27
#
#    Dist    xG  npxG  npxG/Sh  G-xG  np:G-xG
# 0  18.1  59.4  50.2      0.1   5.6      5.8

# %%
min_range
# Out:
# [20,
#  356,
#  100,
#  27.3,
#  9.37,
#  2.63,
#  0.05,
#  0.17,
#  15.1,
#  29.3,
#  28.5,
#  0.07,
#  -9.3,
#  -9.5]

# %%
max_range
# Out:
# [91,
#  673,
#  249,
#  41.1,
#  17.71,
#  6.55,
#  0.14,
#  0.41,
#  18.3,
#  82.0,
#  78.9,
#  0.12,
#  11.2,
#  10.9]

# %%
for x in range(len(df['Squad'])):
    if df['Squad'][x] == 'Manchester Utd':
        values = df.iloc[x].values.tolist()

# %%
values = values[2:]

# %%
values
# Out:
# [65, 513, 211, 41.1, 13.5, 5.55, 0.11, 0.27, 18.1, 59.4, 50.2, 0.1, 5.6, 5.8]

# %%
#title 

title = dict(
    title_name='Manchester United 20/21',
    title_color = 'red',
    subtitle_name = 'Shot Creation',
    subtitle_color = 'black',

    title_fontsize = 18,
    subtitle_fontsize=15
)

endnote = 'Viz. by Chaitanya Shetty'

# %%
radar = Radar(params, min_range, max_range,
              # whether to round any of the labels to integers instead of decimal places
              round_int=[False]*14,
              num_rings=3,  # the number of concentric circles (excluding center circle)
              # if the ring_width is more than the center_circle_radius then
              # the center circle radius will be wider than the width of the concentric circles
              ring_width=1, center_circle_radius=1)

# %%
#We will use mplsoccer’s FontManager to load some fonts from Google Fonts. 
#We borrowed the FontManager from the ridge_map library.

URL1 = ('https://github.com/googlefonts/SourceSerifProGFVersion/blob/main/'
        'fonts/SourceSerifPro-Regular.ttf?raw=true')
serif_regular = FontManager(URL1)
URL2 = ('https://github.com/googlefonts/SourceSerifProGFVersion/blob/main/'
        'fonts/SourceSerifPro-ExtraLight.ttf?raw=true')
serif_extra_light = FontManager(URL2)
URL3 = ('https://github.com/google/fonts/blob/main/ofl/rubikmonoone/'
        'RubikMonoOne-Regular.ttf?raw=true')
rubik_regular = FontManager(URL3)
URL4 = 'https://github.com/googlefonts/roboto/blob/main/src/hinted/Roboto-Thin.ttf?raw=true'
robotto_thin = FontManager(URL4)
URL5 = 'https://github.com/googlefonts/roboto/blob/main/src/hinted/Roboto-Regular.ttf?raw=true'
robotto_regular = FontManager(URL5)
URL6 = 'https://github.com/googlefonts/roboto/blob/main/src/hinted/Roboto-Bold.ttf?raw=true'
robotto_bold = FontManager(URL6)

# %%
fig, ax = radar.setup_axis()  # format axis as a radar
rings_inner = radar.draw_circles(ax=ax, facecolor='#ffc000', edgecolor='#fc5f5f')  # draw circles
radar_output = radar.draw_radar(values, ax=ax,
                                kwargs_radar={'facecolor': '#a7f40a'},
                                kwargs_rings={'facecolor': '#45980c'})  # draw the radar
radar_poly, rings_outer, vertices = radar_output
range_labels = radar.draw_range_labels(ax=ax, fontsize=15,
                                       fontproperties=robotto_thin.prop)  # draw the range labels
param_labels = radar.draw_param_labels(ax=ax, fontsize=15,
                                       fontproperties=robotto_regular.prop)  # draw the param labels
