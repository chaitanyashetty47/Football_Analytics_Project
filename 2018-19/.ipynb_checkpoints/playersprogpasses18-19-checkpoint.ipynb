# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import highlight_text

# %%
df = pd.read_csv('C:\\Users\\Amin\\Documents\\manutd(2012-2021)\\playerpass(18-19).csv')

# %%
df.head()
# Out:
#    Rk                        Player   Nation   Pos            Squad  Age  \
# 0   1  Patrick van Aanholt\5f09991f   nl NED    DF   Crystal Palace   27
# 1   2        Sergio Agüero\4d034881   ar ARG    FW  Manchester City   30
# 2   3           Nathan Aké\eaeca114   nl NED    DF      Bournemouth   23
# 3   4      Marc Albrighton\b827d5b3  eng ENG  FWMF   Leicester City   28
# 4   5    Toby Alderweireld\f7d50789   be BEL    DF        Tottenham   29
#
#    Born   90s  TotalCmp  TotalAtt  ...  LongCmp%  Ast   xA  A-xA  KP  1/3  \
# 0  1990  35.5      1596      1973  ...      59.3    2  3.5  -1.5  31  114
# 1  1988  27.3       653       774  ...      69.2    8  5.3   2.7  33   37
# 2  1995  37.9      1464      1689  ...      73.8    0  0.7  -0.7   4   86
# 3  1989  18.1       458       771  ...      39.2    2  2.8  -0.8  29   47
# 4  1989  32.5      2077      2336  ...      75.6    0  0.6  -0.6   7  189
#
#    PPA  CrsPA  Prog  Matches
# 0   63     10   216  Matches
# 1   41      0    63  Matches
# 2    5      2    68  Matches
# 3   30     15    80  Matches
# 4   26      1   123  Matches
#
# [5 rows x 31 columns]

# %%
# the famous import font code to use Andale Mono
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

# %%
#set default colors
text_color = 'white'
background = '#313332'

# %%
#create a new column for progressive passes per 90
df['per90'] = df['Prog']/df['90s']
df
# Out:
#       Rk                               Player   Nation   Pos            Squad  \
# 0      1         Patrick van Aanholt\5f09991f   nl NED    DF   Crystal Palace
# 1      2               Sergio Agüero\4d034881   ar ARG    FW  Manchester City
# 2      3                  Nathan Aké\eaeca114   nl NED    DF      Bournemouth
# 3      4             Marc Albrighton\b827d5b3  eng ENG  FWMF   Leicester City
# 4      5           Toby Alderweireld\f7d50789   be BEL    DF        Tottenham
# ..   ...                                  ...      ...   ...              ...
# 503  504  Andre-Frank Zambo Anguissa\6bb2c084   cm CMR    MF           Fulham
# 504  505           Davide Zappacosta\7fe90ccd   it ITA    DF          Chelsea
# 505  506         Oleksandr Zinchenko\51cf8561   ua UKR    DF  Manchester City
# 506  507              Kenneth Zohore\5e508d0d   dk DEN    FW     Cardiff City
# 507  508                  Kurt Zouma\ce4246f5   fr FRA    DF          Everton
#
#      Age  Born   90s  TotalCmp  TotalAtt  ...  Ast   xA  A-xA  KP  1/3  PPA  \
# 0     27  1990  35.5      1596      1973  ...    2  3.5  -1.5  31  114   63
# 1     30  1988  27.3       653       774  ...    8  5.3   2.7  33   37   41
# 2     23  1995  37.9      1464      1689  ...    0  0.7  -0.7   4   86    5
# 3     28  1989  18.1       458       771  ...    2  2.8  -0.8  29   47   30
# 4     29  1989  32.5      2077      2336  ...    0  0.6  -0.6   7  189   26
# ..   ...   ...   ...       ...       ...  ...  ...  ...   ...  ..  ...  ...
# 503   22  1995  16.9       930      1061  ...    0  0.4  -0.4   6   95    6
# 504   26  1992   1.4        77        91  ...    0  0.1  -0.1   1    2    1
# 505   21  1996  12.8      1208      1339  ...    3  1.5   1.5  12  131   22
# 506   24  1994   8.4       100       153  ...    1  1.1  -0.1  13    8    3
# 507   23  1994  29.0      1209      1401  ...    2  0.3   1.7   4   67    3
#
#      CrsPA  Prog  Matches     per90
# 0       10   216  Matches  6.084507
# 1        0    63  Matches  2.307692
# 2        2    68  Matches  1.794195
# 3       15    80  Matches  4.419890
# 4        1   123  Matches  3.784615
# ..     ...   ...      ...       ...
# 503      1    73  Matches  4.319527
# 504      1     2  Matches  1.428571
# 505      5    97  Matches  7.578125
# 506      2     7  Matches  0.833333
# 507      0    79  Matches  2.724138
#
# [508 rows x 32 columns]

# %%
#filter the dataframe so it is only players who have played more than 6.5 90's which is about 585 minutes
df = df[df['90s']>=6.5].reset_index()
df
# Out:
#      index   Rk                               Player   Nation   Pos  \
# 0        0    1         Patrick van Aanholt\5f09991f   nl NED    DF
# 1        1    2               Sergio Agüero\4d034881   ar ARG    FW
# 2        2    3                  Nathan Aké\eaeca114   nl NED    DF
# 3        3    4             Marc Albrighton\b827d5b3  eng ENG  FWMF
# 4        4    5           Toby Alderweireld\f7d50789   be BEL    DF
# ..     ...  ...                                  ...      ...   ...
# 370    502  503               Wilfried Zaha\b2bc3b1f   ci CIV    FW
# 371    503  504  Andre-Frank Zambo Anguissa\6bb2c084   cm CMR    MF
# 372    505  506         Oleksandr Zinchenko\51cf8561   ua UKR    DF
# 373    506  507              Kenneth Zohore\5e508d0d   dk DEN    FW
# 374    507  508                  Kurt Zouma\ce4246f5   fr FRA    DF
#
#                Squad  Age  Born   90s  TotalCmp  ...  Ast   xA  A-xA  KP  1/3  \
# 0     Crystal Palace   27  1990  35.5      1596  ...    2  3.5  -1.5  31  114
# 1    Manchester City   30  1988  27.3       653  ...    8  5.3   2.7  33   37
# 2        Bournemouth   23  1995  37.9      1464  ...    0  0.7  -0.7   4   86
# 3     Leicester City   28  1989  18.1       458  ...    2  2.8  -0.8  29   47
# 4          Tottenham   29  1989  32.5      2077  ...    0  0.6  -0.6   7  189
# ..               ...  ...   ...   ...       ...  ...  ...  ...   ...  ..  ...
# 370   Crystal Palace   25  1992  33.7       843  ...    5  5.3  -0.3  53   63
# 371           Fulham   22  1995  16.9       930  ...    0  0.4  -0.4   6   95
# 372  Manchester City   21  1996  12.8      1208  ...    3  1.5   1.5  12  131
# 373     Cardiff City   24  1994   8.4       100  ...    1  1.1  -0.1  13    8
# 374          Everton   23  1994  29.0      1209  ...    2  0.3   1.7   4   67
#
#      PPA  CrsPA  Prog  Matches     per90
# 0     63     10   216  Matches  6.084507
# 1     41      0    63  Matches  2.307692
# 2      5      2    68  Matches  1.794195
# 3     30     15    80  Matches  4.419890
# 4     26      1   123  Matches  3.784615
# ..   ...    ...   ...      ...       ...
# 370   65      9   129  Matches  3.827893
# 371    6      1    73  Matches  4.319527
# 372   22      5    97  Matches  7.578125
# 373    3      2     7  Matches  0.833333
# 374    3      0    79  Matches  2.724138
#
# [375 rows x 33 columns]

# %%
df = df.sort_values(by='per90',ascending=False)

# %%
df = df[df['Pos'] != 'GK']

# %%
df.head(100)
# Out:
#      index   Rk                      Player   Nation Pos            Squad  \
# 169    227  228           Jorginho\45db685d   it ITA  MF          Chelsea
# 242    309  310     Benjamin Mendy\5271c8f1   fr FRA  DF  Manchester City
# 113    148  149        Fernandinho\101da2b5   br BRA  MF  Manchester City
# 83     107  108    Kevin De Bruyne\e46012d4   be BEL  MF  Manchester City
# 283    369  370         Paul Pogba\867239d3   fr FRA  MF   Manchester Utd
# ..     ...  ...                         ...      ...  ..              ...
# 78     100  101    Charlie Daniels\9d107085  eng ENG  DF      Bournemouth
# 287    378  379       Aaron Ramsey\ef619b0b  wls WAL  MF          Arsenal
# 172    230  231  Mathias Jørgensen\0db5d2c8   dk DEN  DF     Huddersfield
# 272    357  358   Emerson Palmieri\e0bc6fdc   it ITA  DF          Chelsea
# 227    292  293    Anthony Martial\8b788c01   fr FRA  FW   Manchester Utd
#
#      Age  Born   90s  TotalCmp  ...  Ast   xA  A-xA  KP  1/3  PPA  CrsPA  \
# 169   26  1991  35.1      2705  ...    0  3.2  -3.2  29  355   46      1
# 242   24  1994  10.0       675  ...    5  1.3   3.7  12   53   26     10
# 113   33  1985  26.4      1812  ...    3  2.6   0.4  23  256   46      0
# 83    27  1991  10.8       626  ...    2  3.4  -1.4  33   65   44      8
# 283   25  1993  33.4      1735  ...    9  5.0   4.0  50  214   66      8
# ..   ...   ...   ...       ...  ...  ...  ...   ...  ..  ...  ...    ...
# 78    31  1986  17.6       781  ...    0  0.6  -0.6   9   59   21      5
# 287   27  1990  14.8       650  ...    6  2.3   3.7  25   54   18      4
# 172   28  1990  23.9       943  ...    1  0.3   0.7   8   77    4      0
# 272   23  1994   7.4       451  ...    0  0.6  -0.6   4   21   14      3
# 227   22  1995  18.0       576  ...    2  2.6  -0.6  32   33   29      5
#
#      Prog  Matches     per90
# 169   301  Matches  8.575499
# 242    85  Matches  8.500000
# 113   213  Matches  8.068182
# 83     86  Matches  7.962963
# 283   262  Matches  7.844311
# ..    ...      ...       ...
# 78     75  Matches  4.261364
# 287    63  Matches  4.256757
# 172   101  Matches  4.225941
# 272    31  Matches  4.189189
# 227    75  Matches  4.166667
#
# [100 rows x 33 columns]

# %%
#Look for Utd Players

df3 = df[df['Squad'] == 'Manchester Utd']
df3
# Out:
#      index   Rk                      Player   Nation   Pos           Squad  \
# 283    369  370         Paul Pogba\867239d3   fr FRA    MF  Manchester Utd
# 319    419  420          Luke Shaw\9c94165b  eng ENG    DF  Manchester Utd
# 120    157  158               Fred\b853e0ad   br BRA    MF  Manchester Utd
# 231    296  297      Nemanja Matić\eb7822d7   rs SRB    MF  Manchester Utd
# 149    197  198      Ander Herrera\436a9dd0   es ESP    MF  Manchester Utd
# 278    363  364    Andreas Pereira\6639e500   br BRA    MF  Manchester Utd
# 368    500  501       Ashley Young\be927d03  eng ENG    DF  Manchester Utd
# 306    405  406     Alexis Sánchez\2c0f8e9e   cl CHI  FWMF  Manchester Utd
# 227    292  293    Anthony Martial\8b788c01   fr FRA    FW  Manchester Utd
# 230    295  296          Juan Mata\29733c72   es ESP  FWMF  Manchester Utd
# 77      97   98        Diogo Dalot\d9565625   pt POR  DFMF  Manchester Utd
# 110    145  146  Marouane Fellaini\87575fd9   be BEL    MF  Manchester Utd
# 239    306  307    Scott McTominay\d93c2511  sct SCO  MFDF  Manchester Utd
# 205    267  268      Jesse Lingard\810e3c74  eng ENG  FWMF  Manchester Utd
# 204    266  267    Victor Lindelöf\f5deef4c   se SWE    DF  Manchester Utd
# 288    380  381    Marcus Rashford\a1d5bd30  eng ENG    FW  Manchester Utd
# 168    226  227         Phil Jones\def899bd  eng ENG    DF  Manchester Utd
# 218    281  282      Romelu Lukaku\5eae500a   be BEL    FW  Manchester Utd
# 325    432  433     Chris Smalling\b6964eb6  eng ENG    DF  Manchester Utd
# 25      29   30        Eric Bailly\a1232f4e   ci CIV    DF  Manchester Utd
#
#      Age  Born   90s  TotalCmp  ...  Ast   xA  A-xA  KP  1/3  PPA  CrsPA  \
# 283   25  1993  33.4      1735  ...    9  5.0   4.0  50  214   66      8
# 319   23  1995  28.8      1666  ...    4  3.5   0.5  33  125   32      8
# 120   25  1993  11.6       656  ...    1  0.9   0.1  15   70    6      2
# 231   29  1988  27.1      1580  ...    0  0.7  -0.7  12  174   21      4
# 149   28  1989  15.6       863  ...    3  1.4   1.6  13   56   10      1
# 278   22  1996   6.7       302  ...    1  0.8   0.2  10   35    8      3
# 368   33  1985  28.5      1372  ...    2  3.3  -1.3  40  114   32     12
# 306   29  1988   9.8       296  ...    3  3.3  -0.3  20   27   26      5
# 227   22  1995  18.0       576  ...    2  2.6  -0.6  32   33   29      5
# 230   30  1988  14.3       619  ...    2  3.3  -1.3  29   63   25      6
# 77    19  1999  11.3       394  ...    2  2.0   0.0  17   23   14      6
# 110   30  1987   8.4       353  ...    1  0.3   0.7   5   30    2      1
# 239   21  1996   9.6       386  ...    0  0.0   0.0   1   29    1      0
# 205   25  1992  18.5       665  ...    2  2.1  -0.1  17   58   13      1
# 204   24  1994  28.9      1323  ...    1  1.0   0.0   4   52    6      0
# 288   20  1997  25.9       534  ...    6  4.2   1.8  38   32   24      3
# 168   26  1992  14.0       684  ...    1  0.5   0.5   3   29    2      0
# 218   25  1993  23.7       377  ...    0  2.4  -2.4  24   25   27      5
# 325   28  1989  23.6       794  ...    0  0.4  -0.4   3   26    1      0
# 25    24  1994   7.1       263  ...    0  0.0   0.0   0    8    0      0
#
#      Prog  Matches     per90
# 283   262  Matches  7.844311
# 319   174  Matches  6.041667
# 120    65  Matches  5.603448
# 231   144  Matches  5.313653
# 149    75  Matches  4.807692
# 278    32  Matches  4.776119
# 368   134  Matches  4.701754
# 306    46  Matches  4.693878
# 227    75  Matches  4.166667
# 230    59  Matches  4.125874
# 77     41  Matches  3.628319
# 110    29  Matches  3.452381
# 239    29  Matches  3.020833
# 205    46  Matches  2.486486
# 204    67  Matches  2.318339
# 288    60  Matches  2.316602
# 168    29  Matches  2.071429
# 218    42  Matches  1.772152
# 325    33  Matches  1.398305
# 25      8  Matches  1.126761
#
# [20 rows x 33 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig.set_facecolor(background)
ax.patch.set_facecolor(background)

#set up our base layer
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color

ax.grid(ls='dotted',lw=.5,color='lightgrey',axis='y',zorder=1)
spines = ['top','bottom','left','right']
for x in spines:
    if x in spines:
        ax.spines[x].set_visible(False)

sns.swarmplot(x='per90',data=df,color='white',zorder=1)

#plot Pogba
plt.scatter(x=7.844311,y=0,c='red',edgecolor='white',s=50,zorder=2)
plt.text(s='Pogba',x=7.84431,y=-.04,c='red')

#plot Shaw
plt.scatter(x=6.041667,y=0,c='blue',edgecolor='white',s=50,zorder=2)
plt.text(s='Shaw',x=6.041667,y=-.04,c='blue')

#plot Fred
plt.scatter(x=5.603448,y=0,c='yellow',edgecolor='white',s=50,zorder=2)
plt.text(s='Fred',x=5.603448,y=.05,c='yellow')

plt.title('Progressive Passes for Man Utd players in the Premier League 2018/19',c=text_color,fontsize=14)

plt.xlabel('Progressive Passes per 90',c=text_color)
# Out:
# Text(0.5, 0, 'Progressive Passes per 90')
