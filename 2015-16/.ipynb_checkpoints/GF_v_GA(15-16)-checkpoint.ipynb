# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
table = pd.read_csv("C:\\Users\\Amin\\Documents\\manutd(2012-2021)\\UtdGFvGA(15-16).csv")
table.head()
# Out:
#    Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Attendance  \
# 0   1   Leicester City  38  23  12   3  68  36  32   81       31998
# 1   2          Arsenal  38  20  11   7  65  36  29   71       59944
# 2   3        Tottenham  38  19  13   6  69  35  34   70       35776
# 3   4  Manchester City  38  19   9  10  71  41  30   66       54041
# 4   5   Manchester Utd  38  19   9  10  49  35  14   66       75286
#
#         Top Team Scorer         Goalkeeper  \
# 0      Jamie Vardy - 24  Kasper Schmeichel
# 1   Olivier Giroud - 16          Petr Čech
# 2       Harry Kane - 25        Hugo Lloris
# 3    Sergio Agüero - 24           Joe Hart
# 4  Anthony Martial - 11       David de Gea
#
#                                        Notes
# 0  → UEFA Champions League via league finish
# 1  → UEFA Champions League via league finish
# 2  → UEFA Champions League via league finish
# 3  → UEFA Champions League via league finish
# 4         → UEFA Europa League via cup win 1

# %%
table['GA'].mean()
# Out:
# 51.3

# %%
table['GF'].mean()
# Out:
# 51.3

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16, 12)

plt.plot(table['GF'],table['GA'],"*")
plt.axvline(table['GF'].mean(), ls = '--', color = 'orange') #60
plt.axhline(table['GA'].mean(), ls = '--', color = 'orange') #45

ax.set_title("GF vs GA (15/16)",size="25")
ax.set_xlabel("Goals Scored(GF)")
ax.set_ylabel("Goals Conceded(GA)")

#plot label for points
for i in range(len(table)):
    if table['Squad'][i] == 'Manchester Utd':
        plt.text(table['GF'][i] + 1, table['GA'][i] , table['Squad'][i], color='maroon' , size="12")
        
    else:
        plt.text(table['GF'][i] +1, table['GA'][i] , table['Squad'][i] )

ax.text(40,40,"Poor Attack\nStrong Defense",color="red",size="10")
ax.text(65,38,"Strong Attack\nStrong Defense",color="red",size="10")
ax.text(40,70,"Poor Attack\nPoor Defense",color="red",size="10")
ax.text(65,70,"Strong Attack\nPoor Defense",color="red",size="10")

plt.show()
