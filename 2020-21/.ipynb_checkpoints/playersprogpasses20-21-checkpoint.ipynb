# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import highlight_text

# %%
df = pd.read_csv('C:\\Users\\Amin\\Documents\\manutd(2012-2021)\\playerspass20-21.csv')

# %%
df.head()
# Out:
#    Rk                                   Player   Nation Pos           Squad  \
# 0   1  Patrick van Aanholt\Patrick-van-Aanholt   nl NED  DF  Crystal Palace
# 1   2              Tammy Abraham\Tammy-Abraham  eng ENG  FW         Chelsea
# 2   3                      Che Adams\Che-Adams  sct SCO  FW     Southampton
# 3   4        Tosin Adarabioyo\Tosin-Adarabioyo  eng ENG  DF          Fulham
# 4   5                            Adrián\Adrian   es ESP  GK       Liverpool
#
#    Age  Born   90s  TotalCmp  TotalAtt  ...  LongCmp%  Ast   xA  A-xA  KP  \
# 0   29  1990  19.7       889      1127  ...      52.0    1  0.8   0.2  11
# 1   22  1997  11.6       149       218  ...      60.0    1  0.9   0.1   8
# 2   24  1996  29.6       443       633  ...      69.9    5  5.8  -0.8  34
# 3   22  1997  32.8      1594      1824  ...      73.6    0  0.4  -0.4   5
# 4   33  1987   3.0        76        99  ...      48.8    0  0.0   0.0   0
#
#    1/3  PPA  CrsPA  Prog  Matches
# ...

# %%
# the famous import font code to use Andale Mono
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

# %%
#set default colors
text_color = '#ff48f1'
background = '#313332'

# %%
#create a new column for progressive passes per 90
df['per90'] = df['Prog']/df['90s']
df
# Out:
#       Rk                                   Player   Nation   Pos  \
# 0      1  Patrick van Aanholt\Patrick-van-Aanholt   nl NED    DF
# 1      2              Tammy Abraham\Tammy-Abraham  eng ENG    FW
# 2      3                      Che Adams\Che-Adams  sct SCO    FW
# 3      4        Tosin Adarabioyo\Tosin-Adarabioyo  eng ENG    DF
# 4      5                            Adrián\Adrian   es ESP    GK
# ..   ...                                      ...      ...   ...
# 527  528                  Andi Zeqiri\Andi-Zeqiri   ch SUI  FWDF
# 528  529  Oleksandr Zinchenko\Oleksandr-Zinchenko   ua UKR    DF
# 529  530                Hakim Ziyech\Hakim-Ziyech   ma MAR  FWMF
# 530  531                    Kurt Zouma\Kurt-Zouma   fr FRA    DF
# 531  532          Martin Ødegaard\Martin-Odegaard   no NOR    MF
#
#                Squad  Age  Born   90s  TotalCmp  TotalAtt  ...  Ast   xA  \
# 0     Crystal Palace   29  1990  19.7       889      1127  ...    1  0.8
# ...

# %%
#filter the dataframe so it is only players who have played more than 6.5 90's which is about 585 minutes
df = df[df['90s']>=6.5].reset_index()
df
# Out:
#      index   Rk                                             Player   Nation  \
# 0        0    1            Patrick van Aanholt\Patrick-van-Aanholt   nl NED
# 1        1    2                        Tammy Abraham\Tammy-Abraham  eng ENG
# 2        2    3                                Che Adams\Che-Adams  sct SCO
# 3        3    4                  Tosin Adarabioyo\Tosin-Adarabioyo  eng ENG
# 4        6    7                                  Ola Aina\Ola-Aina   ng NGA
# ..     ...  ...                                                ...      ...
# 369    526  527  Andre-Frank Zambo Anguissa\Andre-Frank-Zambo-A...   cm CMR
# 370    528  529            Oleksandr Zinchenko\Oleksandr-Zinchenko   ua UKR
# 371    529  530                          Hakim Ziyech\Hakim-Ziyech   ma MAR
# 372    530  531                              Kurt Zouma\Kurt-Zouma   fr FRA
# 373    531  532                    Martin Ødegaard\Martin-Odegaard   no NOR
#
# ...

# %%
df = df.sort_values(by='per90',ascending=False)

# %%
df = df[df['Pos'] != 'GK']

# %%
df.head(100)
# Out:
#      index   Rk                                         Player   Nation   Pos  \
# 9       11   12              Thiago Alcántara\Thiago-Alcantara   es ESP    MF
# 11      14   15  Trent Alexander-Arnold\Trent-Alexander-Arnold  eng ENG    DF
# 178    253  254                    Mateo Kovačić\Mateo-Kovacic   hr CRO    MF
# 89     119  120                Kevin De Bruyne\Kevin-De-Bruyne   be BEL    MF
# 147    200  201              Jordan Henderson\Jordan-Henderson  eng ENG  MFDF
# ..     ...  ...                                            ...      ...   ...
# 66      89   90              Timothy Castagne\Timothy-Castagne   be BEL    DF
# 312    437  438                    Jonjo Shelvey\Jonjo-Shelvey  eng ENG    MF
# 24      29   30              Stuart Armstrong\Stuart-Armstrong  sct SCO    MF
# 121    159  160                    Pablo Fornals\Pablo-Fornals   es ESP  FWMF
# 167    231  232                          Diogo Jota\Diogo-Jota   pt POR    FW
#
# ...

# %%
#Look for Utd Players

df3 = df[df['Squad'] == 'Manchester Utd']
df3
# Out:
#      index   Rk                               Player   Nation   Pos  \
# 114    151  152      Bruno Fernandes\Bruno-Fernandes   pt POR    MF
# 331    468  469              Alex Telles\Alex-Telles   br BRA    DF
# 218    304  305          Nemanja Matić\Nemanja-Matic   rs SRB    MF
# 124    164  165                            Fred\Fred   br BRA    MF
# 269    380  381                Paul Pogba\Paul-Pogba   fr FRA  MFFW
# 311    436  437                  Luke Shaw\Luke-Shaw  eng ENG    DF
# 228    314  315      Scott McTominay\Scott-McTominay  sct SCO    MF
# 350    501  502  Aaron Wan-Bissaka\Aaron-Wan-Bissaka  eng ENG    DF
# 189    268  269      Victor Lindelöf\Victor-Lindelof   se SWE    DF
# 205    288  289          Harry Maguire\Harry-Maguire  eng ENG    DF
# 275    389  390      Marcus Rashford\Marcus-Rashford  eng ENG    FW
# 31      37   38              Eric Bailly\Eric-Bailly   ci CIV    DF
# 214    298  299      Anthony Martial\Anthony-Martial   fr FRA    FW
# ...

# %%
fig, ax = plt.subplots(figsize=(15,7))
fig.set_facecolor(background)
ax.patch.set_facecolor(background)

#set up our base layer
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color

ax.grid(ls='dotted',lw=.5,color='lightgrey',axis='y',zorder=1)
spines = ['top','bottom','left','right']
for x in spines:
    if x in spines:
        ax.spines[x].set_visible(False)

sns.swarmplot(x='per90',data=df,color='white',zorder=1)

#plot Bruno
plt.scatter(x=6.5988,y=0,c='red',edgecolor='white',s=50,zorder=2)
plt.text(s='Bruno',x=6.5988,y=-.04,c='red')

#plot Pogba
plt.scatter(x=5.260,y=0,c='blue',edgecolor='white',s=50,zorder=2)
plt.text(s='Pogba',x=5.220,y=-.04,c='blue')

#plot Shaw
plt.scatter(x=5.220,y=0,c='yellow',edgecolor='white',s=50,zorder=2)
plt.text(s='Shaw',x=5.220,y=.05,c='yellow')

plt.title('Progressive Passes for Utd players in\nthe Premier League 2020/21',c=text_color,fontsize=20)

plt.xlabel('Progressive Passes per 90',c=text_color,fontsize=13)
# Out:
# Text(0.5, 0, 'Progressive Passes per 90')
