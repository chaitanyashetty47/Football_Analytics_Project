# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import highlight_text

# %%
df = pd.read_csv('C:\\Users\\Amin\\Documents\\manutd(2012-2021)\\playerpass(19-20).csv')

# %%
df.head()
# Out:
#    Rk                        Player   Nation Pos           Squad  Age  Born  \
# 0   1  Patrick van Aanholt\5f09991f   nl NED  DF  Crystal Palace   28  1990
# 1   2           Max Aarons\774cf58b  eng ENG  DF    Norwich City   19  2000
# 2   3        Tammy Abraham\f586779e  eng ENG  FW         Chelsea   21  1997
# 3   4            Che Adams\f2bf1b0f  sct SCO  FW     Southampton   23  1996
# 4   5               Adrián\f76e6b4e   es ESP  GK       Liverpool   32  1987
#
#     90s  TotalCmp  TotalAtt  ...  LongCmp%  Ast   xA  A-xA  KP  1/3  PPA  \
# 0  27.9      1227      1558  ...      50.7    2  3.2  -1.2  32   86   25
# 1  36.0      1316      1684  ...      44.8    1  3.4  -2.4  24   43   32
# 2  24.6       288       412  ...      74.3    3  2.5   0.5  18   16    5
# 3  12.3       184       265  ...      50.0    2  1.2   0.8  11   12    3
# 4   9.7       227       314  ...      52.3    0  0.0   0.0   0    3    0
#
#    CrsPA  Prog  Matches
# 0      5   129  Matches
# ...

# %%
# the famous import font code to use Andale Mono
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

# %%
#set default colors
text_color = 'white'
background = '#313332'

# %%
#create a new column for progressive passes per 90
df['per90'] = df['Prog']/df['90s']
df
# Out:
#       Rk                         Player   Nation   Pos            Squad  Age  \
# 0      1   Patrick van Aanholt\5f09991f   nl NED    DF   Crystal Palace   28
# 1      2            Max Aarons\774cf58b  eng ENG    DF     Norwich City   19
# 2      3         Tammy Abraham\f586779e  eng ENG    FW          Chelsea   21
# 3      4             Che Adams\f2bf1b0f  sct SCO    FW      Southampton   23
# 4      5                Adrián\f76e6b4e   es ESP    GK        Liverpool   32
# ..   ...                            ...      ...   ...              ...  ...
# 517  518         Wilfried Zaha\b2bc3b1f   ci CIV  MFFW   Crystal Palace   26
# 518  519  Christoph Zimmermann\2d5f03bf   de GER    DF     Norwich City   26
# 519  520   Oleksandr Zinchenko\51cf8561   ua UKR    DF  Manchester City   22
# 520  521     Richairo Živković\d2d74d9c   nl NED    FW    Sheffield Utd   22
# 521  522            Kurt Zouma\ce4246f5   fr FRA    DF          Chelsea   24
#
# ...

# %%
#filter the dataframe so it is only players who have played more than 6.5 90's which is about 585 minutes
df = df[df['90s']>=6.5].reset_index()
df
# Out:
#      index   Rk                         Player   Nation   Pos  \
# 0        0    1   Patrick van Aanholt\5f09991f   nl NED    DF
# 1        1    2            Max Aarons\774cf58b  eng ENG    DF
# 2        2    3         Tammy Abraham\f586779e  eng ENG    FW
# 3        3    4             Che Adams\f2bf1b0f  sct SCO    FW
# 4        4    5                Adrián\f76e6b4e   es ESP    GK
# ..     ...  ...                            ...      ...   ...
# 381    516  517        Pablo Zabaleta\6813ac34   ar ARG    DF
# 382    517  518         Wilfried Zaha\b2bc3b1f   ci CIV  MFFW
# 383    518  519  Christoph Zimmermann\2d5f03bf   de GER    DF
# 384    519  520   Oleksandr Zinchenko\51cf8561   ua UKR    DF
# 385    521  522            Kurt Zouma\ce4246f5   fr FRA    DF
#
#                Squad  Age  Born   90s  TotalCmp  ...  Ast   xA  A-xA  KP  1/3  \
# 0     Crystal Palace   28  1990  27.9      1227  ...    2  3.2  -1.2  32   86
# ...

# %%
df = df.sort_values(by='per90',ascending=False)

# %%
df = df[df['Pos'] != 'GK']

# %%
df.head(100)
# Out:
#      index   Rk                           Player   Nation   Pos  \
# 384    519  520     Oleksandr Zinchenko\51cf8561   ua UKR    DF
# 79     104  105         Kevin De Bruyne\e46012d4   be BEL    MF
# 277    369  370              Paul Pogba\867239d3   fr FRA    MF
# 9       10   11  Trent Alexander-Arnold\cd1acf9d  eng ENG    DF
# 293    390  391        Andrew Robertson\2e4f5f03  sct SCO    DF
# ..     ...  ...                              ...      ...   ...
# 40      49   50                 Bernard\ab4b3e35   br BRA  MFFW
# 241    322  323              Aaron Mooy\47b7e3af   au AUS  MFFW
# 127    169  170               Joe Gomez\7a11550b  eng ENG    DF
# 370    502  503        Brandon Williams\5e74d6c8  eng ENG    DF
# 382    517  518           Wilfried Zaha\b2bc3b1f   ci CIV  MFFW
#
#                Squad  Age  Born   90s  TotalCmp  ...  Ast    xA  A-xA   KP  \
# 384  Manchester City   22  1996  14.2      1198  ...    0   1.6  -1.6   18
# ...

# %%
#Look for Utd Players

df3 = df[df['Squad'] == 'Manchester Utd']
df3
# Out:
#      index   Rk                      Player   Nation   Pos           Squad  \
# 277    369  370         Paul Pogba\867239d3   fr FRA    MF  Manchester Utd
# 106    137  138    Bruno Fernandes\507c7bdf   pt POR    MF  Manchester Utd
# 380    515  516       Ashley Young\be927d03  eng ENG    DF  Manchester Utd
# 316    421  422          Luke Shaw\9c94165b  eng ENG    DF  Manchester Utd
# 220    294  295      Nemanja Matić\eb7822d7   rs SRB    MF  Manchester Utd
# 116    151  152               Fred\b853e0ad   br BRA    MF  Manchester Utd
# 219    293  294          Juan Mata\29733c72   es ESP  MFFW  Manchester Utd
# 284    380  381    Marcus Rashford\a1d5bd30  eng ENG    FW  Manchester Utd
# 362    491  492  Aaron Wan-Bissaka\9e525177  eng ENG    DF  Manchester Utd
# 231    306  307    Scott McTominay\d93c2511  sct SCO    MF  Manchester Utd
# 370    502  503   Brandon Williams\5e74d6c8  eng ENG    DF  Manchester Utd
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5))
fig.set_facecolor(background)
ax.patch.set_facecolor(background)

#set up our base layer
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color

ax.grid(ls='dotted',lw=.5,color='lightgrey',axis='y',zorder=1)
spines = ['top','bottom','left','right']
for x in spines:
    if x in spines:
        ax.spines[x].set_visible(False)

sns.swarmplot(x='per90',data=df,color='white',zorder=1)

#plot Bruno
plt.scatter(x=6.060606,y=0,c='red',edgecolor='white',s=50,zorder=2)
plt.text(s='Bruno',x=6.060606,y=-.04,c=text_color)

#plot Pogba
plt.scatter(x=8.134328,y=0,c='blue',edgecolor='white',s=50,zorder=2)
plt.text(s='Pogba',x=8.134328,y=-.04,c='blue')

#plot Shaw
plt.scatter(x=5.943396,y=0,c='yellow',edgecolor='white',s=50,zorder=2)
plt.text(s='Young',x=5.943396,y=.05,c='yellow')

plt.title('Progressive Passes for Utd players in the Premier League 2019/20',c=text_color,fontsize=14)

plt.xlabel('Progressive Passes per 90',c=text_color)
# Out:
# Text(0.5, 0, 'Progressive Passes per 90')
