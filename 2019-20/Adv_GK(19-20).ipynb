# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
table = pd.read_csv("C:\\Users\\Amin\\Documents\\manutd(2012-2021)\\UtdAdvGK(19-20).csv")
table.head()
# Out:
#    Rk             Player  Nation Pos            Squad  Age  Born   90s  GA  \
# 0   2            Alisson  br BRA  GK        Liverpool   26  1992  28.3  23
# 1   3  Kepa Arrizabalaga  es ESP  GK          Chelsea   24  1994  33.0  47
# 2   6    Martin Dúbravka  sk SVK  GK    Newcastle Utd   30  1989  38.0  58
# 3   7            Ederson  br BRA  GK  Manchester City   25  1993  34.1  28
# 4   8   Łukasz Fabiański  pl POL  GK         West Ham   34  1985  23.5  34
#
#    PKA  ...  Att.2  Launch%.1  AvgLen.1  Opp  Stp  Stp%  #OPA  #OPA/90  \
# 0    1  ...    170       39.4      38.8  197   16   8.1    37     1.31
# 1    2  ...    199       41.7      39.1  238   18   7.6    21     0.64
# 2    2  ...    337       88.1      64.4  384   20   5.2    14     0.37
# 3    3  ...    139       33.1      35.0  172   12   7.0    38     1.11
# 4    3  ...    194       91.2      63.9  239   10   4.2     5     0.21
#
#    AvgDist  Matches
# 0     17.5  Matches
# 1     15.9  Matches
# 2     12.3  Matches
# 3     17.6  Matches
# 4     11.5  Matches
#
# [5 rows x 34 columns]

# %%
x=table['#OPA/90'].mean()  #avg of defensive actions outside box by GKs in 19/20

# %%
y=table['/90'].mean()      #avg shot stopping of GKs in 19/20

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)


plt.plot(table['#OPA/90'],table['/90'],"*")
plt.axvline(x, ls = '--', color = 'orange')
plt.axhline(y, ls = '--', color = 'orange')

ax.set_title("PL Goalkeeping Actions (19/20)",size="25")
ax.set_ylabel("Post-Shot xG - Goals Allowed(GA) p90")
ax.set_xlabel("Defensive Action outside Penalty Area p90 (Sweeping Actions)")

#Quadrant Labels
ax.text(0.2,0.3,"Great Shot Stopper\nPoor Sweeper",color="green",size="13")
ax.text(0.2,-0.28,"Poor Shot Stopper\nPoor Sweeper",color="green",size="13")
ax.text(0.96,0.3,"Great Shot Stopper\nGreat Sweeper",color="green",size="13")
ax.text(0.96,-0.28,"Poor Shot Stopper\nGreat Sweeper",color="green",size="13")

#plot label for points
for i in range(len(table)):
    if table['Player'][i] == 'David de Gea':
        plt.text(table['#OPA/90'][i] + .01 , table['/90'][i] -.01, table['Player'][i], color='maroon' , size="12")
    elif table['Player'][i]=='Jordan Pickford':
        plt.text(table['#OPA/90'][i] + .01, table['/90'][i] , table['Player'][i])
    
    
    elif table['Player'][i]=='Łukasz Fabiański':
        plt.text(table['#OPA/90'][i] - .01, table['/90'][i] -.015 , table['Player'][i])
    elif table['Player'][i]=='Alisson':
        plt.text(table['#OPA/90'][i] - .025 , table['/90'][i] -.015 , table['Player'][i]) 
    else:
        plt.text(table['#OPA/90'][i] +.01, table['/90'][i] -.01 , table['Player'][i] )
        

plt.show()
